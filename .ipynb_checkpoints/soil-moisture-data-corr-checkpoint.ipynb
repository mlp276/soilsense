# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

# %%
df = pd.read_csv('sensorData01.csv')

# %%
df.head()
# Out:
#            Time  Temperature  Capacitive Reading
# 0  1.741394e+09         29.1                 362
# 1  1.741394e+09         29.0                 361
# 2  1.741394e+09         29.1                 361
# 3  1.741394e+09         29.3                 361

# %%
df.columns = ['Time in Millisecond Since UTC Epoch', 'Temperature in Celsius', 'Capacitive Reading']

# %%
df.head()
# Out:
#    Time in Millisecond Since UTC Epoch  Temperature in Celsius  \
# 0                         1.741394e+09                    29.1
# 1                         1.741394e+09                    29.0
# 2                         1.741394e+09                    29.1
# 3                         1.741394e+09                    29.3
#
#    Capacitive Reading
# 0                 362
# 1                 361
# 2                 361
# 3                 361

# %%
df.tail()
# Out:
#    Time in Millisecond Since UTC Epoch  Temperature in Celsius  \
# 0                         1.741394e+09                    29.1
# 1                         1.741394e+09                    29.0
# 2                         1.741394e+09                    29.1
# 3                         1.741394e+09                    29.3
#
#    Capacitive Reading
# 0                 362
# 1                 361
# 2                 361
# 3                 361

# %%
df2 = pd.read_csv('plantDatabase.csv')

# %%
df2.head()
# Out:
#   Unnamed: 0 Jersey-Friendly Yards Plant Database                Unnamed: 2  \
# 0          #                                 Name               Common Name
# 1          1             Pycnanthemum tenuifolium  Narrowleaf Mountain mint
# 2          2                        Achillea spp.                    Yarrow
# 3          3                       Aesculus flava            Yellow Buckeye
# 4          4                    Begonia cultivars                   Begonia
#
#          Unnamed: 3         Unnamed: 4          Unnamed: 5     Unnamed: 6  \
# 0              Type  New Jersey Native           Soil Type  Soil Moisture
# 1  Flower_Perennial                Yes                Clay      Dry_Moist
# 2  Flower_Perennial                 No  Loam_Organic_Sandy            Dry
# 3              Tree                Yes  Loam_Organic_Sandy      Dry_Moist
# 4     Flower_Annual                 No  Loam_Organic_Sandy      Dry_Moist
#
#                                        Unnamed: 7         Unnamed: 8  \
# 0                                         Soil pH  Drought Tolerance
# 1                           Acidic_SlightlyAcidic               High
# 2                   Acidic_SlightlyAcidic_Neutral               High
# 3  Acidic_SlightlyAcidic_Neutral_SlightlyAlkaline                Low
# 4                   Acidic_SlightlyAcidic_Neutral             Medium
#
#       Unnamed: 9                 Unnamed: 10     Unnamed: 11
# 0  Optimal Light                 Light Range  Hardiness Zone
# 1        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 2        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 3        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 4   PartialShade  FullSun_PartialShade_Shade     6a_6b_7a_7b

# %%
df2.columns = ['#', 'Name', 'Common Name', 'Type', 'New Jersey Native?', 'Soil Type', 'Soil Moisture', 'Soil pH', 'Drought Tolerance', 'Optimal Light', 'Light Range', 'Hardiness Zone']

# %%
df2.head()
# Out:
#    #                      Name               Common Name              Type  \
# 0  #                      Name               Common Name              Type
# 1  1  Pycnanthemum tenuifolium  Narrowleaf Mountain mint  Flower_Perennial
# 2  2             Achillea spp.                    Yarrow  Flower_Perennial
# 3  3            Aesculus flava            Yellow Buckeye              Tree
# 4  4         Begonia cultivars                   Begonia     Flower_Annual
#
#   New Jersey Native?           Soil Type  Soil Moisture  \
# 0  New Jersey Native           Soil Type  Soil Moisture
# 1                Yes                Clay      Dry_Moist
# 2                 No  Loam_Organic_Sandy            Dry
# 3                Yes  Loam_Organic_Sandy      Dry_Moist
# 4                 No  Loam_Organic_Sandy      Dry_Moist
#
#                                           Soil pH  Drought Tolerance  \
# 0                                         Soil pH  Drought Tolerance
# 1                           Acidic_SlightlyAcidic               High
# 2                   Acidic_SlightlyAcidic_Neutral               High
# 3  Acidic_SlightlyAcidic_Neutral_SlightlyAlkaline                Low
# 4                   Acidic_SlightlyAcidic_Neutral             Medium
#
#    Optimal Light                 Light Range  Hardiness Zone
# 0  Optimal Light                 Light Range  Hardiness Zone
# 1        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 2        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 3        FullSun        FullSun_PartialShade     6a_6b_7a_7b
# 4   PartialShade  FullSun_PartialShade_Shade     6a_6b_7a_7b

# %%
df3 = df2.drop(df2.index[0])

# %%
df3.head()
# Out:
#    #                      Name               Common Name              Type  \
# 1  1  Pycnanthemum tenuifolium  Narrowleaf Mountain mint  Flower_Perennial
# 2  2             Achillea spp.                    Yarrow  Flower_Perennial
# 3  3            Aesculus flava            Yellow Buckeye              Tree
# 4  4         Begonia cultivars                   Begonia     Flower_Annual
# 5  5         Brassica oleracea        Ornamental Cabbage     Flower_Annual
#
#   New Jersey Native?           Soil Type Soil Moisture  \
# 1                Yes                Clay     Dry_Moist
# 2                 No  Loam_Organic_Sandy           Dry
# 3                Yes  Loam_Organic_Sandy     Dry_Moist
# 4                 No  Loam_Organic_Sandy     Dry_Moist
# 5                 No        Loam_Organic     Moist_Wet
#
#                                           Soil pH Drought Tolerance  \
# 1                           Acidic_SlightlyAcidic              High
# 2                   Acidic_SlightlyAcidic_Neutral              High
# 3  Acidic_SlightlyAcidic_Neutral_SlightlyAlkaline               Low
# 4                   Acidic_SlightlyAcidic_Neutral            Medium
# 5        Slightly Acidic_Neutral_SlightlyAlkaline               NaN
#
#   Optimal Light                 Light Range Hardiness Zone
# 1       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 2       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 3       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 4  PartialShade  FullSun_PartialShade_Shade    6a_6b_7a_7b
# 5       FullSun                     FullSun    6a_6b_7a_7b

# %%
df4 = df3.drop(columns=['#'])

# %%
df4.head()
# Out:
#                        Name               Common Name              Type  \
# 1  Pycnanthemum tenuifolium  Narrowleaf Mountain mint  Flower_Perennial
# 2             Achillea spp.                    Yarrow  Flower_Perennial
# 3            Aesculus flava            Yellow Buckeye              Tree
# 4         Begonia cultivars                   Begonia     Flower_Annual
# 5         Brassica oleracea        Ornamental Cabbage     Flower_Annual
#
#   New Jersey Native?           Soil Type Soil Moisture  \
# 1                Yes                Clay     Dry_Moist
# 2                 No  Loam_Organic_Sandy           Dry
# 3                Yes  Loam_Organic_Sandy     Dry_Moist
# 4                 No  Loam_Organic_Sandy     Dry_Moist
# 5                 No        Loam_Organic     Moist_Wet
#
#                                           Soil pH Drought Tolerance  \
# 1                           Acidic_SlightlyAcidic              High
# 2                   Acidic_SlightlyAcidic_Neutral              High
# 3  Acidic_SlightlyAcidic_Neutral_SlightlyAlkaline               Low
# 4                   Acidic_SlightlyAcidic_Neutral            Medium
# 5        Slightly Acidic_Neutral_SlightlyAlkaline               NaN
#
#   Optimal Light                 Light Range Hardiness Zone
# 1       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 2       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 3       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 4  PartialShade  FullSun_PartialShade_Shade    6a_6b_7a_7b
# 5       FullSun                     FullSun    6a_6b_7a_7b

# %%
len(df4)
# Out:
# 20

# %%
dbfinal = df4

# %%
dbfinal.head()
# Out:
#                        Name               Common Name              Type  \
# 1  Pycnanthemum tenuifolium  Narrowleaf Mountain mint  Flower_Perennial
# 2             Achillea spp.                    Yarrow  Flower_Perennial
# 3            Aesculus flava            Yellow Buckeye              Tree
# 4         Begonia cultivars                   Begonia     Flower_Annual
# 5         Brassica oleracea        Ornamental Cabbage     Flower_Annual
#
#   New Jersey Native?           Soil Type Soil Moisture  \
# 1                Yes                Clay     Dry_Moist
# 2                 No  Loam_Organic_Sandy           Dry
# 3                Yes  Loam_Organic_Sandy     Dry_Moist
# 4                 No  Loam_Organic_Sandy     Dry_Moist
# 5                 No        Loam_Organic     Moist_Wet
#
#                                           Soil pH Drought Tolerance  \
# 1                           Acidic_SlightlyAcidic              High
# 2                   Acidic_SlightlyAcidic_Neutral              High
# 3  Acidic_SlightlyAcidic_Neutral_SlightlyAlkaline               Low
# 4                   Acidic_SlightlyAcidic_Neutral            Medium
# 5        Slightly Acidic_Neutral_SlightlyAlkaline               NaN
#
#   Optimal Light                 Light Range Hardiness Zone
# 1       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 2       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 3       FullSun        FullSun_PartialShade    6a_6b_7a_7b
# 4  PartialShade  FullSun_PartialShade_Shade    6a_6b_7a_7b
# 5       FullSun                     FullSun    6a_6b_7a_7b

# %%
s1 = df

# %%
s1.head()
# Out:
#    Time in Millisecond Since UTC Epoch  Temperature in Celsius  \
# 0                         1.741394e+09                    29.1
# 1                         1.741394e+09                    29.0
# 2                         1.741394e+09                    29.1
# 3                         1.741394e+09                    29.3
#
#    Capacitive Reading
# 0                 362
# 1                 361
# 2                 361
# 3                 361

# %%
s1.dtypes
# Out:
# Time in Millisecond Since UTC Epoch    float64
# Temperature in Celsius                 float64
# Capacitive Reading                       int64
# dtype: object

# %%
dbfinal.dtypes
# Out:
# Name                  object
# Common Name           object
# Type                  object
# New Jersey Native?    object
# Soil Type             object
# Soil Moisture         object
# Soil pH               object
# Drought Tolerance     object
# Optimal Light         object
# Light Range           object
# Hardiness Zone        object
# dtype: object

# %%
import numpy as np

# %%
conditions = [
    (s1['Capacitive Reading'] <= 650),
    (s1['Capacitive Reading'] > 650) & (s1['Capacitive Reading'] <= 1100),
    (s1['Capacitive Reading'] > 1100) & (s1['Capacitive Reading'] <= 1550),
    (s1['Capacitive Reading'] > 1550)
]

values = ['Dry', 'Dry_Moist', 'Moist', 'Moist_Wet']

s1['Soil Moisture'] = np.select(conditions, values, default=pd.NaT)

s1.head()
# Out:
#    Time in Millisecond Since UTC Epoch  Temperature in Celsius  \
# 0                         1.741394e+09                    29.1
# 1                         1.741394e+09                    29.0
# 2                         1.741394e+09                    29.1
# 3                         1.741394e+09                    29.3
#
#    Capacitive Reading Soil Moisture
# 0                 362           Dry
# 1                 361           Dry
# 2                 361           Dry
# 3                 361           Dry

# %%
s1.dtypes
# Out:
# Time in Millisecond Since UTC Epoch    float64
# Temperature in Celsius                 float64
# Capacitive Reading                       int64
# Soil Moisture                           object
# dtype: object

# %%
#extract an array of plants that have the specified soil moisture from the plant database, 
#and store the array into the respective lists

dryplants = dbfinal.loc[dbfinal['Soil Moisture'] == 'Dry', 'Common Name']
print(dryplants)

drymoist = dbfinal.loc[dbfinal['Soil Moisture'] == 'Dry_Moist', 'Common Name']
print(drymoist)

moistplants = dbfinal.loc[dbfinal['Soil Moisture'] == 'Moist', 'Common Name']
print(moistplants)

moistwet = dbfinal.loc[dbfinal['Soil Moisture'] == 'Moist_Wet', 'Common Name']
print(moistwet)
# Out:
# 2                  Yarrow
# 8       Black Huckleberry
# 10     Lindheimer’s Muhly
# 11        Little Bluestem
# 13    Japanese Tree Lilac
# 15             Arborvitae
# 17      Lowbush Blueberry
# 20                 Zinnia
# Name: Common Name, dtype: object
# 1     Narrowleaf Mountain mint
# 3               Yellow Buckeye
# 4                      Begonia
# 9             Spotted Geranium
# 16           American Basswood
# 18           New York Ironweed
# 19                   Arrowwood
# Name: Common Name, dtype: object
# 14    King of the Meadow
# Name: Common Name, dtype: object
# 5     Ornamental Cabbage
# 6       Crested Woodfern
# 7             Sweetbells
# 12             Woolgrass
# Name: Common Name, dtype: object

# %%
con2 = [
    (s1['Soil Moisture'] == 'Dry'),
    (s1['Soil Moisture'] == 'Dry_Moist'),
    (s1['Soil Moisture'] == 'Moist'),
    (s1['Soil Moisture'] == 'Moist_Wet')
]

#convert the lists of plants with a specified soil moisture into strings so they  
#can be returned as recommendations in a new column of the soil moisture dataframe

dpst = " ".join(str(x) for x in dryplants)
dmst = " ".join(str(x) for x in drymoist)
mpst = " ".join(str(x) for x in moistplants)
mwst = " ".join(str(x) for x in moistwet)

val2 = [dpst, dmst, mpst, mwst]

s1['Plant Recommendations'] = np.select(con2, val2, default=pd.NaT)
s1.head()
# Out:
#    Time in Millisecond Since UTC Epoch  Temperature in Celsius  \
# 0                         1.741394e+09                    29.1
# 1                         1.741394e+09                    29.0
# 2                         1.741394e+09                    29.1
# 3                         1.741394e+09                    29.3
#
#    Capacitive Reading Soil Moisture  \
# 0                 362           Dry
# 1                 361           Dry
# 2                 361           Dry
# 3                 361           Dry
#
#                                Plant Recommendations
# 0  Yarrow Black Huckleberry Lindheimer’s Muhly Li...
# 1  Yarrow Black Huckleberry Lindheimer’s Muhly Li...
# 2  Yarrow Black Huckleberry Lindheimer’s Muhly Li...
# 3  Yarrow Black Huckleberry Lindheimer’s Muhly Li...

# %%
for i in s1['Plant Recommendations']:
    if i == dpst:
        print(dryplants)
    elif i == dmst:
        print (drymoist)
    elif i == mpst:
        print (moistplants)
    elif i == mwst:
        print (moistwet)
# Out:
# 2                  Yarrow
# 8       Black Huckleberry
# 10     Lindheimer’s Muhly
# 11        Little Bluestem
# 13    Japanese Tree Lilac
# 15             Arborvitae
# 17      Lowbush Blueberry
# 20                 Zinnia
# Name: Common Name, dtype: object
# 2                  Yarrow
# 8       Black Huckleberry
# 10     Lindheimer’s Muhly
# 11        Little Bluestem
# 13    Japanese Tree Lilac
# 15             Arborvitae
# 17      Lowbush Blueberry
# 20                 Zinnia
# Name: Common Name, dtype: object
# 2                  Yarrow
# 8       Black Huckleberry
# 10     Lindheimer’s Muhly
# 11        Little Bluestem
# 13    Japanese Tree Lilac
# 15             Arborvitae
# 17      Lowbush Blueberry
# 20                 Zinnia
# Name: Common Name, dtype: object
# 2                  Yarrow
# 8       Black Huckleberry
# 10     Lindheimer’s Muhly
# 11        Little Bluestem
# 13    Japanese Tree Lilac
# 15             Arborvitae
# 17      Lowbush Blueberry
# 20                 Zinnia
# Name: Common Name, dtype: object
